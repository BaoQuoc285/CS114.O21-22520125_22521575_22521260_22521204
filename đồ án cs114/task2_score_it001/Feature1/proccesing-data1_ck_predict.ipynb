# %%
import sys  # System-specific parameters and functions
import numpy as np  # Fundamental package for scientific computing with Python
import pandas as pd  # Powerful data structures for data manipulation and analysis
from datetime import datetime  # Basic date and time types
import warnings  # Warning control
warnings.filterwarnings('ignore')  # Ignore warnings

# %%
df = pd.read_csv('/kaggle/input/competition3/data-tbtl/annonimized.csv')
df = df[(df['is_final'] != 0) | (df['pre_score'] != 10000)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288863 entries, 0 to 295197
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   concat('it001',`assignment_id`)  288863 non-null  object
#  1   concat('it001',`problem_id`)     288863 non-null  object
#  2   concat('it001', username)        288863 non-null  object
#  3   is_final                         288863 non-null  int64
#  4   status                           288863 non-null  object
#  5   pre_score                        288863 non-null  int64
#  6   coefficient                      288863 non-null  int64
#  7   concat('it001',`language_id`)    288863 non-null  object
#  8   created_at                       288863 non-null  object
#  9   updated_at                       288863 non-null  object
#  10  judgement                        288863 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 26.4+ MB

# %%
df = df.rename(columns={"concat('it001',`assignment_id`)": 'assignment_id'})
df = df.rename(columns={"concat('it001',`problem_id`)":'problem_id'})
df = df.rename(columns={"concat('it001', username)":'username'})

# %%
df = df.drop(["concat('it001',`language_id`)", 'updated_at'], axis=1)

# %%
def calculate_frequency_vector(student_df):
    a = pd.to_datetime(student_df['created_at'], format='%m-%d %H:%M:%S', errors='coerce').dt.hour
    a = a.dropna()  # Drop rows with NaT (errors in parsing)

    hour_counts = a.value_counts().sort_index()
    frequency_vector = np.zeros(24)
    for hour, count in hour_counts.items():
        hour = int(hour)
        frequency_vector[hour] = count
    return frequency_vector

# Dictionary to store frequency vectors for each student
frequency_vectors = {}

# Iterate over each unique student and calculate their frequency vector
for username in df["username"].unique():
    student_df = df[df["username"] == username]
    frequency_vectors[username] = calculate_frequency_vector(student_df)

# %%
frequency_df = pd.DataFrame.from_dict(frequency_vectors, orient='index', columns=[f'hour_{i}' for i in range(24)]).reset_index()
frequency_df.rename(columns={'index': "username"}, inplace=True)

# %%
df = df.merge(frequency_df, on="username")

# %%
fixed_year = 2024  # Chọn một năm bất kỳ
df['created_at'] = [f"{fixed_year}-{date}" for date in df['created_at']]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
def adjust_year(date):
    if date.month >= 9:
        return date.replace(year=date.year - 1)
    return date

# Áp dụng hàm này vào cột 'created_at'
df['created_at'] = df['created_at'].apply(adjust_year)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %% [markdown]
# # Số lượng assignment và problem

# %%
num_assigmnet1 = df.groupby(["username"])['assignment_id'].nunique().reset_index().rename(columns={'assignment_id': 'num_assigmnet1'})
num_problem = df.groupby(["username"])["problem_id"].nunique().reset_index().rename(columns={'problem_id': 'num_problem'})
submit_count = df.groupby(["username"])["problem_id"].count().reset_index().rename(columns={'problem_id': 'submit_count'})

# %% [markdown]
# # Số lần nộp SCORE và Khác

# %%
count_non_score = df[df['status'] != 'SCORE'].groupby("username").size().reset_index().rename(columns={0: 'count_NON_SCORE'})
count_score = df[df['status'] == 'SCORE'].groupby("username").size().reset_index().rename(columns={0: 'count_SCORE'})

# %% [markdown]
# # Số lần nộp is_final

# %%
count_is_final = df[df['is_final'] == 1].groupby("username").size().reset_index().rename(columns={0: 'count_is_final'})

# %% [markdown]
# # Điểm số trung bình

# %%
mean_pre_score = df.groupby(["username"])["pre_score"].mean().reset_index().rename(columns={'pre_score': 'mean_pre_score'})

# %% [markdown]
# # Tỉ số số lần nộp và assigment

# %%
count_of_assignments = df.groupby(["username"])["problem_id"].count() / df.groupby(["username"])["assignment_id"].nunique()

# %%
count_of_assignments = count_of_assignments.reset_index().rename(columns={0: 'count_of_assignments'})

# %%
count_of_assignments
# Out:
#                                       username  count_of_assignments
# 0     00b6dd4fc7eb817e03708c532016ef30ce564a61             19.857143
# 1     00bef8afee8f3c595d535c9c03c490cac1a4f021             27.333333
# 2     01122b3ef7e59b84189e65985305f575d6bdf83c             27.857143
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183             23.750000
# 4     013de369c439ab0ead8aa7da64423aa395a8be39             13.250000
# ...                                        ...                   ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627              7.555556
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312             42.500000
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076             72.333333
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51             13.428571
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359             35.700000
#
# [1489 rows x 2 columns]

# %% [markdown]
# # Tỉ số số lần nộp và problem

# %%
count_of_problems = df.groupby(["username"])["problem_id"].count() / df.groupby(["username"])["problem_id"].nunique()
count_of_problems = count_of_problems.reset_index().rename(columns={0: 'count_of_problems'})

# %%
tgia = df.groupby(["username", "problem_id"])["pre_score"].max()
tgia = tgia.groupby(["username"]).apply(lambda x: (x != 10000).sum()) / tgia.groupby(["username"]).count()

# %%
tgia = tgia.reset_index().rename(columns={"pre_score": 'ratio_not_10000'})

# %%
mean_submit_problem = df.groupby(["username", "problem_id"])["problem_id"].count()
mean_submit_problem = mean_submit_problem.groupby("username").mean().reset_index().rename(columns={"problem_id": 'mean_submit_problem'})

# %%
mean_submit_assignment = df.groupby(["username", "assignment_id"])["assignment_id"].count()
mean_submit_assignment = mean_submit_problem.groupby("username").mean().reset_index().rename(columns={"assignment_id": 'mean_submit_assignment'})

# %%
mean_time_problem = df.groupby(["username", "problem_id"])['created_at'].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600)
mean_time_problem = (mean_time_problem.groupby(["username"]).mean()/10).reset_index().rename(columns={"created_at": 'mean_submit_problem'})

# %%
mean_time_assignment = df.groupby(["username", "assignment_id"])['created_at'].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600)
mean_time_assignment = (mean_time_assignment.groupby(["username"]).mean()/10).reset_index().rename(columns={"created_at": 'mean_submit_assignment'})

# %%
df = df.merge(num_assigmnet1, on="username")
df = df.merge(num_problem, on="username")
df = df.merge(submit_count, on="username")
df = df.merge(count_non_score, on="username")
df = df.merge(count_score, on="username")
df = df.merge(count_is_final, on="username")
df = df.merge(mean_pre_score, on="username")
df = df.merge(count_of_assignments, on="username")
df = df.merge(tgia, on="username")
df = df.merge(count_of_problems, on="username")
df = df.merge(mean_submit_problem, on="username")
df = df.merge(mean_time_problem, on="username")

# %%
df = df.drop(['problem_id_x'],axis = 1)

# %%
df = df.drop(['problem_id_y'],axis = 1)

# %%
df = df.drop(['assignment_id'],axis = 1)

# %%
df.columns
# Out:
# Index(['username', 'is_final', 'status', 'pre_score', 'coefficient',
#        'created_at', 'judgement', 'hour_0', 'hour_1', 'hour_2', 'hour_3',
#        'hour_4', 'hour_5', 'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10',
#        'hour_11', 'hour_12', 'hour_13', 'hour_14', 'hour_15', 'hour_16',
#        'hour_17', 'hour_18', 'hour_19', 'hour_20', 'hour_21', 'hour_22',
#        'hour_23', 'num_assigmnet1', 'num_problem', 'submit_count',
#        'count_NON_SCORE', 'count_SCORE', 'count_is_final', 'mean_pre_score',
#        'count_of_assignments', 'ratio_not_10000', 'mean_submit_problem_x',
#        'mean_submit_problem_y'],
#       dtype='object')

# %%
# !pip install lightgbm catboost
# Out:
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (4.2.0)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.2.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.7.5)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.10/site-packages (from catboost) (2.2.1)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.2.3)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.metrics import mean_squared_error as MSE
import lightgbm as lgb
import optuna
from sklearn.model_selection import cross_validate
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
from sklearn.ensemble import VotingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer

# %%
train_term1 = df.drop(['is_final','status','pre_score','coefficient','created_at','judgement'], axis = 1)

# %%
test_term1 = train_term1

# %%
test_term1
# Out:
#                                         username  hour_0  hour_1  hour_2  \
# 0       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 1       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 2       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 3       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 4       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# ...                                          ...     ...     ...     ...
# 288284  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288285  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288286  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288287  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288288  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
#
#         hour_3  hour_4  hour_5  hour_6  hour_7  hour_8  ...  num_problem  \
# 0          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 1          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 2          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 3          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 4          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# ...        ...     ...     ...     ...     ...     ...  ...          ...
# 288284     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288285     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288286     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288287     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288288     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
#
#         submit_count  count_NON_SCORE  count_SCORE  count_is_final  \
# 0                136               34          102              58
# 1                136               34          102              58
# 2                136               34          102              58
# 3                136               34          102              58
# 4                136               34          102              58
# ...              ...              ...          ...             ...
# 288284           216               45          171              98
# 288285           216               45          171              98
# 288286           216               45          171              98
# 288287           216               45          171              98
# 288288           216               45          171              98
#
#         mean_pre_score  count_of_assignments  ratio_not_10000  \
# 0          5202.000000             27.200000         0.034483
# 1          5202.000000             27.200000         0.034483
# 2          5202.000000             27.200000         0.034483
# 3          5202.000000             27.200000         0.034483
# 4          5202.000000             27.200000         0.034483
# ...                ...                   ...              ...
# 288284     5680.976852             19.636364         0.020408
# 288285     5680.976852             19.636364         0.020408
# 288286     5680.976852             19.636364         0.020408
# 288287     5680.976852             19.636364         0.020408
# 288288     5680.976852             19.636364         0.020408
#
#         mean_submit_problem_x  mean_submit_problem_y
# 0                    2.344828               0.177979
# 1                    2.344828               0.177979
# 2                    2.344828               0.177979
# 3                    2.344828               0.177979
# 4                    2.344828               0.177979
# ...                       ...                    ...
# 288284               2.204082               1.677821
# 288285               2.204082               1.677821
# 288286               2.204082               1.677821
# 288287               2.204082               1.677821
# 288288               2.204082               1.677821
#
# [288289 rows x 36 columns]

# %%
test_term1.drop_duplicates(subset='username', keep='first', inplace=True)

# %%
qt_train = pd.read_csv('/kaggle/input/competition3/public_it001/ck-public.csv')

# %%
qt_train.isnull().sum()
qt_train = qt_train.rename(columns={"hash":'username'})
qt_train.dropna(inplace=True)
train_term1 = train_term1.merge(qt_train, on='username', how='inner')
train_term1.drop_duplicates(subset='username', keep='first', inplace=True)
train_term1.dropna(inplace=True)

# %%
train_term1.columns
# Out:
# Index(['username', 'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5',
#        'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'num_assigmnet1',
#        'num_problem', 'submit_count', 'count_NON_SCORE', 'count_SCORE',
#        'count_is_final', 'mean_pre_score', 'count_of_assignments',
#        'ratio_not_10000', 'mean_submit_problem_x', 'mean_submit_problem_y',
#        'CK'],
#       dtype='object')

# %%
X_train= train_term1.drop(columns=["CK", "username"])
y = train_term1['CK']
y = y.astype(float)

# %%
y = np.asarray(y)
X_pca = np.asarray(X_train)

# %%
def objective_lgb(trial):
    params = {
        "objective": "regression",
        "metric": "rmse",
        "n_estimators": 1000,
        "verbosity": -1,
        "bagging_freq": 1,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 2**10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.05, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        'device': 'gpu',
    }
    cv = KFold(n_splits=5, shuffle=True,random_state = 42)
    r2_list = []

    for train_index, test_index in cv.split(X_pca,y):
        X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = lgb.LGBMRegressor(**params)

        model.fit(X_train_fold, y_train)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        r2_list.append(r2)

    return np.mean(r2_list)

# %%
def objective_cat(trial):
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
        'depth': trial.suggest_int('depth', 3, 8),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10),
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'eval_metric': 'RMSE',
        'random_seed': 42,
        'verbose': False,
        'loss_function':'RMSE',
        'task_type': 'GPU'
    }

    cv = KFold(n_splits=5, shuffle=True,random_state = 42)
    r2_list = []

    for train_index, test_index in cv.split(X_pca,y):
        X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model = CatBoostRegressor(**params)
        model.fit(X_train_fold, y_train, eval_set=(X_test, y_test), early_stopping_rounds=10)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        r2_list.append(r2)

    return np.mean(r2_list)

# %%
study_lgb = optuna.create_study(direction="minimize")
study_lgb.optimize(objective_lgb, n_trials=30)
print('Best parameters for LightGBM:', study_lgb.best_params)
# Out:
# [I 2024-07-03 09:13:14,073] A new study created in memory with name: no-name-9e0b2c02-ea6d-44dc-890d-471127d6ecc4
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [I 2024-07-03 09:13:21,022] Trial 0 finished with value: 0.14300190065332039 and parameters: {'learning_rate': 0.005060014292989446, 'num_leaves': 868, 'subsample': 0.5621936257979607, 'colsample_bytree': 0.706592098755122, 'min_data_in_leaf': 85}. Best is trial 0 with value: 0.14300190065332039.
# [I 2024-07-03 09:13:39,791] Trial 1 finished with value: 0.11572614187783985 and parameters: {'learning_rate': 0.006496062427810224, 'num_leaves': 572, 'subsample': 0.37949767626588726, 'colsample_bytree': 0.3655738314864311, 'min_data_in_leaf': 78}. Best is trial 1 with value: 0.11572614187783985.
# [I 2024-07-03 09:13:43,910] Trial 2 finished with value: 0.14799556828508778 and parameters: {'learning_rate': 0.0013566211182370123, 'num_leaves': 34, 'subsample': 0.7575935525535287, 'colsample_bytree': 0.5372469070428187, 'min_data_in_leaf': 34}. Best is trial 1 with value: 0.11572614187783985.
# [I 2024-07-03 09:13:56,275] Trial 3 finished with value: 0.1222496268225913 and parameters: {'learning_rate': 0.04096770190291746, 'num_leaves': 834, 'subsample': 0.9492451661905591, 'colsample_bytree': 0.850886637426243, 'min_data_in_leaf': 15}. Best is trial 1 with value: 0.11572614187783985.
# [I 2024-07-03 09:14:03,627] Trial 4 finished with value: 0.15929594312639495 and parameters: {'learning_rate': 0.005861890440895677, 'num_leaves': 331, 'subsample': 0.802264698733218, 'colsample_bytree': 0.16423806810348976, 'min_data_in_leaf': 17}. Best is trial 1 with value: 0.11572614187783985.
# [I 2024-07-03 09:14:05,589] Trial 5 finished with value: 0.12892873319114181 and parameters: {'learning_rate': 0.023724287423029216, 'num_leaves': 915, 'subsample': 0.5469781089202441, 'colsample_bytree': 0.3165917664809503, 'min_data_in_leaf': 91}. Best is trial 1 with value: 0.11572614187783985.
# [I 2024-07-03 09:14:27,729] Trial 6 finished with value: 0.093717217288209 and parameters: {'learning_rate': 0.028597745673660687, 'num_leaves': 91, 'subsample': 0.48750962322451546, 'colsample_bytree': 0.2749502620309289, 'min_data_in_leaf': 21}. Best is trial 6 with value: 0.093717217288209.
# [I 2024-07-03 09:14:48,230] Trial 7 finished with value: 0.14196786367813832 and parameters: {'learning_rate': 0.0015059770213215675, 'num_leaves': 133, 'subsample': 0.20248663084901447, 'colsample_bytree': 0.623059716550681, 'min_data_in_leaf': 16}. Best is trial 6 with value: 0.093717217288209.
# [I 2024-07-03 09:15:07,598] Trial 8 finished with value: 0.06673369653747471 and parameters: {'learning_rate': 0.001622198853128775, 'num_leaves': 308, 'subsample': 0.2658656023279279, 'colsample_bytree': 0.9220681039270457, 'min_data_in_leaf': 59}. Best is trial 8 with value: 0.06673369653747471.
# [I 2024-07-03 09:15:10,747] Trial 9 finished with value: 0.17237679578388918 and parameters: {'learning_rate': 0.0033942640396011853, 'num_leaves': 939, 'subsample': 0.8826061896618571, 'colsample_bytree': 0.6482310303192452, 'min_data_in_leaf': 71}. Best is trial 8 with value: 0.06673369653747471.
# [I 2024-07-03 09:15:22,915] Trial 10 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.08747687304484446, 'num_leaves': 529, 'subsample': 0.08550463977921427, 'colsample_bytree': 0.9478050072311782, 'min_data_in_leaf': 57}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:15:34,902] Trial 11 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.09251242278394135, 'num_leaves': 520, 'subsample': 0.068771394861525, 'colsample_bytree': 0.9816209409095835, 'min_data_in_leaf': 56}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:15:46,856] Trial 12 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.09252116663956357, 'num_leaves': 589, 'subsample': 0.05347073905508992, 'colsample_bytree': 0.9887266000939445, 'min_data_in_leaf': 48}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:15:58,990] Trial 13 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.07606732527403388, 'num_leaves': 691, 'subsample': 0.06552717954159032, 'colsample_bytree': 0.7968580389751123, 'min_data_in_leaf': 50}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:16:11,916] Trial 14 finished with value: 0.054952151903164895 and parameters: {'learning_rate': 0.015313111991561268, 'num_leaves': 379, 'subsample': 0.2010691058125372, 'colsample_bytree': 0.7937224174495416, 'min_data_in_leaf': 64}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:16:32,270] Trial 15 finished with value: 0.04613220624504013 and parameters: {'learning_rate': 0.04873344556156106, 'num_leaves': 451, 'subsample': 0.31810403761031847, 'colsample_bytree': 0.9947924201687939, 'min_data_in_leaf': 39}. Best is trial 10 with value: -0.0021548576134207574.
# [I 2024-07-03 09:17:08,244] Trial 16 finished with value: -0.10322767972091802 and parameters: {'learning_rate': 0.054955345436813706, 'num_leaves': 706, 'subsample': 0.0934264690572541, 'colsample_bytree': 0.47778639139653495, 'min_data_in_leaf': 1}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:17:29,046] Trial 17 finished with value: 0.14612764115778262 and parameters: {'learning_rate': 0.016455114560191053, 'num_leaves': 732, 'subsample': 0.413674588864431, 'colsample_bytree': 0.4548781250069085, 'min_data_in_leaf': 32}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:17:41,217] Trial 18 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.05350642929957759, 'num_leaves': 702, 'subsample': 0.16875956263831499, 'colsample_bytree': 0.4892856576150237, 'min_data_in_leaf': 96}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:17:44,408] Trial 19 finished with value: 0.11040073391799181 and parameters: {'learning_rate': 0.030820664134675827, 'num_leaves': 203, 'subsample': 0.635853674512124, 'colsample_bytree': 0.16213155779111954, 'min_data_in_leaf': 41}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:18:14,082] Trial 20 finished with value: 0.09354218565225687 and parameters: {'learning_rate': 0.01423230554891924, 'num_leaves': 780, 'subsample': 0.15280980975045608, 'colsample_bytree': 0.08403753183352969, 'min_data_in_leaf': 2}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:18:26,492] Trial 21 finished with value: -0.0021548576134207574 and parameters: {'learning_rate': 0.09654137721890099, 'num_leaves': 501, 'subsample': 0.08320746833262398, 'colsample_bytree': 0.8873228831492521, 'min_data_in_leaf': 59}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:18:46,063] Trial 22 finished with value: 0.07133285275812107 and parameters: {'learning_rate': 0.06317952103760245, 'num_leaves': 611, 'subsample': 0.2759041864654237, 'colsample_bytree': 0.723046865417087, 'min_data_in_leaf': 68}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:19:10,084] Trial 23 finished with value: -0.026083290630444945 and parameters: {'learning_rate': 0.04341643269931687, 'num_leaves': 450, 'subsample': 0.128533500899041, 'colsample_bytree': 0.5534961545130915, 'min_data_in_leaf': 4}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:19:52,639] Trial 24 finished with value: 0.01375847685074585 and parameters: {'learning_rate': 0.0357065412020049, 'num_leaves': 430, 'subsample': 0.127997774907723, 'colsample_bytree': 0.412927448654485, 'min_data_in_leaf': 1}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:20:18,065] Trial 25 finished with value: 0.03534682905428701 and parameters: {'learning_rate': 0.0587718138354876, 'num_leaves': 270, 'subsample': 0.23324608302972338, 'colsample_bytree': 0.5715838927265501, 'min_data_in_leaf': 8}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:20:40,878] Trial 26 finished with value: 0.12374300549998803 and parameters: {'learning_rate': 0.020905786941912627, 'num_leaves': 645, 'subsample': 0.36163989786884276, 'colsample_bytree': 0.25802771823206694, 'min_data_in_leaf': 24}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:21:02,882] Trial 27 finished with value: 0.05613282658620176 and parameters: {'learning_rate': 0.0417165177279738, 'num_leaves': 520, 'subsample': 0.14518574477093016, 'colsample_bytree': 0.6076804285920758, 'min_data_in_leaf': 9}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:21:25,200] Trial 28 finished with value: -0.01889064858637135 and parameters: {'learning_rate': 0.07104102328279906, 'num_leaves': 431, 'subsample': 0.29521251443695784, 'colsample_bytree': 0.6966851473287474, 'min_data_in_leaf': 26}. Best is trial 16 with value: -0.10322767972091802.
# [I 2024-07-03 09:21:49,926] Trial 29 finished with value: 0.15141538663797657 and parameters: {'learning_rate': 0.009102206420961543, 'num_leaves': 214, 'subsample': 0.4646331494374192, 'colsample_bytree': 0.6894065490182616, 'min_data_in_leaf': 25}. Best is trial 16 with value: -0.10322767972091802.
# Best parameters for LightGBM: {'learning_rate': 0.054955345436813706, 'num_leaves': 706, 'subsample': 0.0934264690572541, 'colsample_bytree': 0.47778639139653495, 'min_data_in_leaf': 1}

# %%
study_cat = optuna.create_study(direction='minimize')
study_cat.optimize(objective_cat, n_trials=30
. Best is trial 12 with value: 0.11213647073491528.
# [I 2024-07-03 09:25:31,848] Trial 27 finished with value: 0.16598344713137375 and parameters: {'learning_rate': 0.015948416490248637, 'depth': 5, 'l2_leaf_reg': 0.05330268442705707, 'iterations': 233}. Best is trial 12 with value: 0.11213647073491528.
# [I 2024-07-03 09:25:37,194] Trial 28 finished with value: 0.16015984708062886 and parameters: {'learning_rate': 0.026135038131835712, 'depth': 5, 'l2_leaf_reg': 0.0011139174229212615, 'iterations': 156}. Best is trial 12 with value: 0.11213647073491528.
# [I 2024-07-03 09:25:44,346] Trial 29 finished with value: 0.1567606298330208 and parameters: {'learning_rate': 0.012894642693387992, 'depth': 4, 'l2_leaf_reg': 0.026191916268110533, 'iterations': 441}. Best is trial 12 with value: 0.11213647073491528.
# Best parameters for CatBoost: {'learning_rate': 0.010769901330643285, 'depth': 6, 'l2_leaf_reg': 0.3856188819903941, 'iterations': 111}

# %%
lgb_best_params = study_lgb.best_params
cat_best_params = study_cat.best_params

kf = KFold(n_splits=5, shuffle=True, random_state=42)
voting_r2 = []

for train_index, test_index in kf.split(X_pca):
    X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
    y_train, y_test = y[train_index], y[test_index]

    lgb_model = lgb.LGBMRegressor(**lgb_best_params)
    cat_model = CatBoostRegressor(**cat_best_params)

    voting_model = VotingRegressor(estimators=[
        ('lgb', lgb_model),
        ('cat', cat_model)
    ])
    cat_model.fit(X_train_fold, y_train)
    lgb_model.fit(X_train_fold, y_train)
    voting_model.fit(X_train_fold, y_train)
    y_pred = voting_model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    voting_r2.append(r2)

print(f'Voting Regressor R^2: {np.mean(voting_r2):.4f} ± {np.std(voting_r2):.4f}')
# Out:
# 0:	learn: 2.0984897	total: 11.7ms	remaining: 1.29s
# 1:	learn: 2.0944430	total: 14.8ms	remaining: 808ms
# 2:	learn: 2.0894689	total: 17.6ms	remaining: 634ms
# 3:	learn: 2.0852741	total: 20.4ms	remaining: 546ms
# 4:	learn: 2.0806083	total: 23.1ms	remaining: 491ms
# 5:	learn: 2.0774311	total: 25.8ms	remaining: 451ms
# 6:	learn: 2.0747484	total: 28.5ms	remaining: 424ms
# 7:	learn: 2.0719113	total: 31.1ms	remaining: 401ms
# 8:	learn: 2.0685625	total: 33.8ms	remaining: 383ms
# 9:	learn: 2.0651236	total: 36.6ms	remaining: 370ms
# 10:	learn: 2.0624785	total: 39.6ms	remaining: 360ms
# 11:	learn: 2.0597790	total: 42.1ms	remaining: 347ms
# 12:	learn: 2.0569108	total: 44.6ms	remaining: 336ms
# 13:	learn: 2.0538890	total: 47.3ms	remaining: 328ms
# 14:	learn: 2.0507483	total: 50.2ms	remaining: 321ms
# 15:	learn: 2.0470127	total: 52.8ms	remaining: 313ms
# 16:	learn: 2.0433224	total: 55.5ms	remaining: 307ms
# 17:	learn: 2.0392176	total: 58.1ms	remaining: 300ms
# 18:	learn: 2.0355332	total: 60.9ms	remaining: 295ms
# 19:	learn: 2.0328988	total: 63.5ms	remaining: 289ms
# 20:	learn: 2.0308940	total: 66.1ms	remaining: 283ms
# 21:	learn: 2.0268376	total: 68.9ms	remaining: 279ms
# 22:	learn: 2.0225737	total: 71.7ms	remaining: 274ms
# 23:	learn: 2.0185494	total: 74.6ms	remaining: 270ms
remaining: 0us
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Voting Regressor R^2: 0.1502 ± 0.0590

# %%
import joblib

# %%
joblib.dump(voting_model, 'voting_regressor.joblib')
joblib.dump(lgb_model, 'LGBMRegressor.joblib')
joblib.dump(cat_model, 'CatBoostRegressor.joblib')
# Out:
# ['CatBoostRegressor.joblib']

# %%
common_cols = train_term1.columns.intersection(test_term1.columns)

# Tạo DataFrame mới chỉ chứa các cột chung
train_term1_common = train_term1[common_cols]
df_test_common = test_term1[common_cols]

# Tìm các hàng khác nhau
different_rows = pd.concat([train_term1_common, df_test_common]).drop_duplicates(keep=False)

different_rows.reset_index(drop=True, inplace=True)
different_rows.head(5)
# Out:
#                                    username  hour_0  hour_1  hour_2  hour_3  \
# 0  ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0     1.0
# 1  ba12c0a2cb367af0467e479c03507c71a805d291     1.0     3.0     7.0    10.0
# 2  b7298b0fe50443a623af9b56792b330c2d052845     0.0    24.0    28.0    39.0
# 3  c60be70309789b39355dc612f36e37090ccad5dc     0.0     4.0    20.0    13.0
# 4  a22a58c5be8aa2c2700619e37f2b7a6e4efa7e6b     0.0     6.0     0.0     0.0
#
#    hour_4  hour_5  hour_6  hour_7  hour_8  ...  num_problem  submit_count  \
# 0     6.0     8.0     5.0    11.0    17.0  ...           58           136
# 1    25.0     5.0    16.0    28.0    36.0  ...          112           313
# 2    22.0     2.0     2.0     4.0     7.0  ...          110           246
# 3     9.0     4.0     5.0    10.0    11.0  ...           83           172
# 4     1.0     1.0    19.0    38.0    55.0  ...          103           277
#
#    count_NON_SCORE  count_SCORE  count_is_final  mean_pre_score  \
# 0               34          102              58     5202.000000
# 1               74          239             117     5137.111821
# 2               36          210             110     5982.589431
# 3               26          146              83     6237.773256
# 4               38          239             103     5370.649819
#
#    count_of_assignments  ratio_not_10000  mean_submit_problem_x  \
# 0             27.200000         0.034483               2.344828
# 1             52.166667         0.000000               2.794643
# 2             49.200000         0.018182               2.236364
# 3             17.200000         0.084337               2.072289
# 4             25.181818         0.048544               2.689320
#
#    mean_submit_problem_y
# 0               0.177979
# 1               4.387548
# 2               1.547971
# 3               0.556678
# 4               0.961238
#
# [5 rows x 36 columns]

# %%
X_test= different_rows.drop(columns=["username"])

# %%
X_pca = np.asarray(X_test)

# %%
y_pre1 = lgb_model.predict(X_pca)
y_pre2 = cat_model.predict(X_pca)
y_pre3 = voting_model.predict(X_pca)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1

# %%
username = different_rows['username'].to_list()
results1 = []
for i, value in enumerate(y_pre1):
    results1.append((username[i], value))
df = pd.DataFrame(results1, columns=['file_name', 'label'])
df.to_csv('outputCK_1.csv', index=False, header=False)

# %%
results2 = []
for i, value in enumerate(y_pre2):
    results2.append((username[i], value))
df = pd.DataFrame(results2, columns=['file_name', 'label'])
df.to_csv('outputCK_2.csv', index=False, header=False)

# %%
results3 = []
for i, value in enumerate(y_pre3):
    results3.append((username[i], value))
df = pd.DataFrame(results3, columns=['file_name', 'label'])
df.to_csv('outputCK_3.csv', index=False, header=False)
